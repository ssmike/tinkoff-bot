# %%
# %matplotlib inline
import time
import re

chats = []
sentences = []
f = open("Tinkoff Chat Sample Big.txt", "r+")

idx = 0
while True:
    if not f.readline():
        break
    f.readline()
    f.readline()
    s = f.readline().strip()
    chat = []
    while (not '--------' in s):
        s = s[9:]
        if s[:6] == "Клиент":
            s = s[8:]
        else:
            s = s[11:]
        s = re.split(r"[\:\(\)-\.!?\s]+", s)
        s = [x.lower() for x in s if x]
        chat.append(s)
        s = f.readline().strip()
    f.readline()
    chats.append(chat)
    sentences.extend(chat)
    #if (idx % 1000 == 0):
        #print (chat)
        #print(idx)
    #idx += 1
    
#print(len(chats))
#print(len(sentences))

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

words = dict()
all_words = 0
for sentence in sentences:
    for word in sentence:
        all_words += 1
        if word in words:
            words[word] += 1
        else:
            words[word] = 1

for elem in words.keys():
    words[elem] = math.log(words[elem] / all_words)
    
lens = [len(chat) for chat in chats]
plt.figure(figsize=(20, 20))
plt.xlim(xmin=1, xmax=50)
plt.hist(lens, bins=300)
plt.show()

print(np.argmax(np.array(lens)))

#for idx in range(20, 50):
cur_chat = chats[16622]
print(len(cur_chat))
for sentence in cur_chat:
    log_prob = 0
    entropy = 0
    gini = 0
    for word in sentence:
        log_prob += words[word]
        entropy -= words[word] * math.exp(words[word])
        gini += math.exp(words[word]) * (1 - math.exp(words[word]))
    print(sentence, round(log_prob, 5), round(entropy, 5), round(gini, 5))
print()
# Out:
# 16622
# 297
# ['добрый', 'день', 'узнал', 'тут', 'о', '"техническом', 'сбое"', 'который', 'вроде', 'как', 'был', 'в', 'банке', 'пару', 'дней', 'назад', 'из', 'за', 'которого', 'обычным', 'нормальным', 'клиентам', 'заблокировали', 'дистанционное', 'обслуживание', 'сижу', 'вот', 'теперь', 'в', 'небольшом', 'шоке', 'и', 'честно', 'говоря', 'несколько', 'нарушен', 'ситуацией', 'как', 'вообще', 'такое', 'могло', 'произойти', 'и', 'какие', 'теперь', 'гарантии', 'что', 'подобное', 'не', 'произойдёт', 'и', 'со', 'мной', 'надеюсь', 'на', 'ответ', 'старшего', 'специалиста'] -495.74389 0.82583 0.18212
# ['здравствуйте'] -4.61557 0.04568 0.0098
# ['упс', 'не', 'нарушен', 'а', 'напуган'] -50.15888 0.09333 0.02076
# ['последствия', 'сбоя', 'были', 'оперативно', 'устранены', 'ограничение', 'дистанционного', 'обслуживание', 'мы', 'вводим', 'только', 'при', 'наличии', 'на', 'то', 'оснований'] -146.71845 0.1651 0.03363
# ['и', 'всё'] -12.50885 0.05677 0.01252
# ['во', 'первых', 'не', 'так', 'уж', 'и', 'оперативно', 'были', 'они', 'устранены', 'давайте', 'будем', 'объективными'] -113.00165 0.15175 0.03228
# ['имя', 'отчество', 'банк', 'имеет', 'право', 'ограничить', 'дистанционное', 'обслуживание', 'информация', 'об', 'этом', 'есть', 'в', 'er<j/'] -115.36365 0.19302 0.04338
# ['укбо'] -10.27428 0.00035 3e-05
# ['во', 'вторых', 'представители', 'банка', 'вообще', 'говорили', 'что', 'решения', 'принята', 'на', 'основании', 'каких', 'то', 'пунктов', 'условий', 'обслуживания', 'которые', 'суд', 'уже', 'признал', 'незаконными'] -192.36195 0.18451 0.03763
# ['и', 'затем', '"увы', 'решение', 'пересмотру', 'не', 'подлежит', '"'] -72.72495 0.1252 0.02827
# ['это', 'как', 'вообще'] -18.82798 0.05773 0.01084
# ['это', 'вот', 'такое', 'отношения', 'банка', 'к', 'лояльным', 'клиентам'] -68.41152 0.06902 0.01198
# ['банк', 'не', 'согласен', 'с', 'решением', 'суда', 'и', 'будет', 'его', 'оспаривать', 'повторюсь', 'банк', 'ограничивает', 'дистанционное', 'обслуживание', 'при', 'наличии', 'на', 'то', 'причин'] -158.36779 0.37966 0.08084
# ['а', 'потом', 'внезапно', 'это', 'оказалось', 'техническим', 'сбоем'] -64.47942 0.06024 0.011
# ['окей', 'оспаривает', 'но', 'решения', 'суда', 'и', 'банк', 'обязан', 'исполнять', 'насколько', 'я', 'знаю', 'но', 'вопрос', 'не', 'в', 'этом'] -135.2822 0.36883 0.08527
# ['если', 'говорить', 'про', 'сбой', 'то', 'он', 'затронул', 'несколько', 'клиентов', 'все', 'остальные', 'случаи', 'вынужденная', 'мера', 'которой', 'банк', 'воспользовался'] -156.20832 0.14261 0.02639
# ['несколько', 'только', 'лишь', 'несколько', 'клиентов', 'отписались', 'об', 'этом', 'на', 'форуме', 'и', 'в', 'соц', 'сетях'] -115.66849 0.28776 0.06763
# ['вы', 'хотите', 'сказать', 'что', 'все', 'эти', '"несколько', 'клиентов"', 'знают', 'что', 'такое', 'и', 'могут', 'написать', 'отзыв'] -122.44966 0.21335 0.04319
# ['просто', 'вы', 'ознакомились', 'с', 'ситуацией', 'других', 'клиентов', 'из', 'сми', 'или', 'других', 'источников', 'возможно', 'по', 'описанию', 'в', 'статьях', 'она', 'кажется', 'абсурдной', 'но', 'банк', 'не', 'огарничивает', 'обслуживание', 'без', 'наличия', 'на', 'то', 'веских', 'причин'] -270.63086 0.52544 0.11713
# ['в', 'одном', 'месте', 'написано', 'представители', 'говорят', 'о', '"несколько', 'десятков"', 'вы', 'о', '"нескольких', 'клиентах"'] -131.5193 0.18634 0.04483
# ['погодите'] -12.3723 5e-05 0.0
# ['я', 'лишь', 'сказал', 'что', 'сбой', 'о', 'ктором', 'вы', 'пишите', 'распространился', 'на', 'сравнительно', 'небольшое', 'количество', 'клиентов', 'клиентов', 'которым', 'банк', 'ограничил', 'обслуживание', 'вне', 'сбоя', 'больше'] -207.34622 0.29555 0.0631
# ['котором'] -8.89878 0.00122 0.00014
# ['сначала', 'банк', 'в', 'лице', 'представителя', 'пишет', '"увы', 'решение', 'пересмотру', 'не', 'подлежит', '"'] -110.86041 0.20295 0.04999
# ['потом', 'о', 'техническом', 'сбое', 'одному', 'и', 'тому', 'же', 'клиенту'] -81.55267 0.08205 0.01646
# ['я', 'этого', 'вообще', 'не', 'понимаю'] -30.86375 0.14458 0.03292
# ['я', 'не', 'могу', 'комментировать', 'какую', 'либо', 'ситуацию', 'по', 'конкретному', 'клиенту', 'если', 'вы', 'им', 'не', 'являетесь', 'мне', 'неизвестна', 'причина', 'по', 'которой', 'клиенту', 'предоставили', 'такую', 'информацию'] -184.47015 0.49218 0.10721
# ['меня', 'не', 'интересуют', 'клиенты', 'которые', 'действительно', 'что', 'то', 'химичат'] -72.13462 0.15435 0.03218
# ['я', 'речь', 'веду', 'у', 'нормальных', 'клиентах', 'к', 'которым', 'и', 'отношусь'] -93.11933 0.17762 0.03874
# ['какие', 'у', 'меня', 'теперь', 'могут', 'быть', 'гарантии', 'что', 'меня', 'условно', 'завтра', 'так', 'же', 'не', 'отключат', 'без', 'объяснения', 'причин', 'и', 'скажут', '"увы', 'решение', 'пересмотру', 'не', 'подлежит', '"'] -219.32685 0.34517 0.07119
# ['хотя', 'это', 'окажется', 'каким', 'то', 'очередным', '"техническим', 'сбоем"'] -85.05726 0.06142 0.01139
# ['у', 'нас', 'большинство', 'именно', 'таких', 'как', 'вы', 'они', 'пользуются', 'картами', 'годами', 'и', 'не', 'испытывают', 'каких', 'либо', 'неудобств', 'если', 'возникает', 'сбой', 'наши', 'коллеги', 'стараются', 'его', 'устранить', 'наиболее', 'оперативно'] -243.436 0.31729 0.06581
# ['я', 'сильно', 'уливлён'] -30.65585 0.06612 0.01569
# ['грубо', 'говоря', 'по', 'ошибке', 'в', 'выборку', 'тех', 'которые', '"', 'что', 'то', 'химичат"', 'вошли', 'обычные', 'клиенты', 'мы', 'это', 'заметили', 'и', 'ситуацию', 'исправили', 'принесли', 'извинения', 'клиентам'] -215.31834 0.33822 0.07621
# ['а', 'если', 'бы', 'эти', 'которые', '"по', 'ошибке"', 'не', 'подняли', 'бы', 'шумиху', 'и', 'я', 'уверен', 'что', 'таких', 'отключенных', '"по', 'ошибке"', 'но', 'не', 'написавших', 'об', 'этом', 'нигде', 'очень', 'много'] -234.7515 0.41137 0.08803
# ['это', 'простая', 'логика', 'активных', 'пользователей', 'соц', 'сетей', 'и', 'профильных', 'форумов', 'очень', 'мало', 'или', 'вы', 'хотите', 'сказать', 'что', 'по', 'ошибке', 'только', 'они', 'и', 'были', 'отключены'] -216.34837 0.33051 0.06831
# ['да', 'и', 'даже', 'не', 'в', 'этом', 'дело', 'я', 'не', 'понимаю', 'вот', 'этого', 'отношения', 'банка', 'к', 'нормальным', 'клиентам', 'сначала', 'сказать', 'что', '"увы', 'до', 'свиданья"', 'и', 'только', 'спустя', 'время', 'уже', 'начать', 'разбираться', 'и', 'признать', 'в', 'итоге', 'ошибку'] -271.01439 0.76006 0.17409
# ['мы', 'блокируем', 'дистанционное', 'обслуживание', 'клиентам', 'которые', 'нарушают', 'условия', 'обслуживания', 'мы', 'никогда', 'не', 'скрывали', 'этого', 'если', 'необходимо', 'отключить', 'дистанционное', 'обслуживание', 'мы', 'сделаем', 'это', 'без', 'каких', 'либо', 'прикрытий', 'в', 'виде', 'сбоя'] -244.55563 0.34863 0.07522
# ['почему', 'бы', 'сразу', 'не', 'начать', 'разрбираться'] -51.63968 0.08361 0.01802
# ['как', 'ни', 'странно', 'но', 'ошибку', 'мы', 'тоже', 'не', 'мгновенно', 'обнаружили', 'поэтому', 'некоторое', 'время', 'могли', 'сообщать', 'стандартную', 'фразу'] -145.07278 0.15606 0.03066
# ['и', 'вот', 'за', 'это', 'вам', 'огроменный', 'минус'] -51.46665 0.16326 0.0338
# ['я', 'всегда', 'был', 'вашим', 'лояльным', 'клиентом', 'и', 'всем', 'вас', 'советовал'] -82.89643 0.18175 0.03901
# ['банк', 'не', 'скрывает', 'что', 'вина', 'на', 'нашей', 'стороне', 'но', 'повторюсь', 'те', 'клиенты', 'которые', 'пользуются', 'счетами', 'без', 'нарушений', 'продложают', 'это', 'делать'] -177.96106 0.25893 0.0549
# ['но', 'то', 'что', 'происходит', 'в', 'этой', 'ситуации', 'это', 'уже', 'за', 'гранью'] -75.79579 0.26444 0.05876
# ['сбои', 'и', 'человеческий', 'фактор', 'это', 'те', 'явления', 'которые', 'в', 'том', 'числе', 'банкам'] -113.47152 0.19779 0.04762
# ['так', 'вы', 'поймите', 'меня', 'правильно', 'ребята', 'которых', 'отключили', '"по', 'ошибке"', 'тоже', 'были', 'нормальными', 'клиентами', 'насколько', 'я', 'понимаю', 'как', 'и', 'я'] -167.09496 0.31381 0.06736
# ['нет'] -5.30601 0.02633 0.00494
# ['но', 'теперь', 'я', 'понимаю', 'что', 'банк', 'меня', 'как', 'нормального', 'клиента', 'может', 'отключить', 'в', 'любой', 'момент'] -102.59658 0.32476 0.07214
# ['а', 'потом', 'ссылаться', 'на', 'какие', 'то', 'пункты', 'укбо', 'и', 'говорить', '"увы', 'решение', 'пересмотру', 'не', 'подлежит', '"'] -139.10985 0.26427 0.05822
# ['чтобы', 'правильно', 'оцентить', 'данную', 'ситуацию', 'необходимо', 'знать', 'ее', 'комплексно', 'вы', 'сейчас', 'ознакомлены', 'только', 'с', 'позицией', 'одной', 'стороны'] -148.419 0.17769 0.03415
# ['как', 'это', 'нет', 'ошибку', 'то', 'признали', 'признали', 'извинилась', 'да', 'мили', 'какие', 'то', 'начислили', 'в', 'качестве', 'компенсации', 'тоже', 'да', 'и', 'они', 'не', 'нормальные'] -173.34694 0.44602 0.09753
# ['всё', 'возможно'] -15.10266 0.00888 0.00122
# ['11', '11', '|', 'имя', 'грубо', 'говоря', 'по', 'ошибке', 'в', 'выборку', 'тех', 'которые', '"', 'что', 'то', 'химичат"', 'вошли', 'обычные', 'клиенты', 'мы', 'это', 'заметили', 'и', 'ситуацию', 'исправили', 'принесли', 'извинения', 'клиентам'] -241.08046 0.466 0.10449
# ['но', 'мне', 'как', 'клиенту', 'и', 'не', 'зачем', 'знать', 'ситуацию', 'со', 'всех', 'сторон', 'я', 'лишь', 'смотрю', 'на', 'ответы', 'и', 'действия', 'представителей', 'банка'] -158.89772 0.41471 0.09097
# ['поставьте', 'себя', 'на', 'моё', 'место'] -46.36116 0.07301 0.01754
# ['действия', 'просты', 'ошибка', 'исправлена', 'те', 'клиенты', 'которые', 'нарушают', 'условия', 'лишены', 'дистанционного', 'обслуживания'] -125.80686 0.01617 0.002
# ['я', 'вижу', 'что', 'нормального', 'клиента', 'сначала', 'грубо', 'говоря', 'посылают', 'в', 'ответ', 'на', 'его', 'публичную', 'жалобу', 'а', 'затем', 'когда', 'шум', 'поднялся', 'говорят', '"ой', 'ошибочка', 'вышла', 'извините"'] -247.37034 0.34534 0.08032
# ['как', 'мне', 'на', 'это', 'реагировать'] -33.26533 0.15292 0.03279
# ['видимо', 'об', 'ошибке', 'стало', 'известно', 'не', 'сразу'] -59.53055 0.07513 0.01665
# ['так', 'а', 'зачем', 'сразу', 'то', 'посылать', 'да', 'ещё', 'и', 'публично', 'меня', 'это', 'больше', 'всего', 'поражает'] -114.968 0.24273 0.0465
# ['я', 'просто', 'понимаю', 'что', 'так', 'же', 'и', 'меня', 'могут', 'послать', 'в', 'три', 'прекрасный', 'момент', 'ведь', 'я', 'вряд', 'ли', 'чем', 'то', 'отличаюсь', 'от', 'тех', 'клиентов', 'которые', '"по', 'ошибке"'] -211.26276 0.47597 0.1044
# ['и', 'каковы', 'теперь', 'могут', 'быть', 'мои', 'логичные', 'шаги'] -74.76184 0.07068 0.01446
# ['по', 'факту', 'обнаружения', 'ошибки', 'мы', 'выполнили', 'необходимые', 'действия', 'для', 'исправления', 'ситуации'] -94.33617 0.10731 0.02124
# ['просто', 'такими', 'действиями', 'и', 'ответами', 'сотрудников', 'банк', 'сильно', 'подрывает', 'к', 'себе', 'доверие', 'а', 'это', 'три', 'из', 'главных', 'активов', 'банка', 'это', 'не', 'я', 'придумал', 'и', 'не', 'только', 'я', 'говорю'] -233.85143 0.55009 0.11839
# ['уф', 'ну', 'что', 'вы', 'об', 'одном', 'и', 'том', 'же'] -66.10848 0.16173 0.03336
# ['я', 'просто', 'уже', 'сообщил', 'вам', 'информацию', 'по', 'данной', 'ситуации'] -57.99908 0.2136 0.04556
# ['я', 'понимаю', 'что', 'вам', 'имя', 'не', 'приятно', 'отвечать', 'на', 'мои', 'неудобные', 'вопросы', 'но', 'мне', 'нужно', 'понять', 'отношение', 'к', 'клиенту', 'банка', 'в', 'целом'] -158.94519 0.52522 0.11775
# ['мы', 'не', 'можем', 'гарантировать', 'что', 'все', 'клиенты', 'будут', 'всегда', 'с', 'дистанционным', 'обслуживанием'] -92.3324 0.2099 0.04285
# ['вы', 'просто', 'можете', 'перевести', 'меня', 'на', 'старшего', 'специалиста', 'если', 'это', 'возможно'] -75.17938 0.24301 0.05067
# ['возможно', 'он', 'мне', 'даст', 'понять', 'актуальное', 'состояние', 'в', 'банке'] -73.43628 0.16115 0.03845
# ['сейчас', 'прошу', 'ожидать', 'несколько', 'минут'] -31.89226 0.07898 0.01431
# ['тем', 'более', 'что', 'я', 'сейчас', 'выбираю', 'банк', 'для', 'открытия', 'р/с', 'компании'] -81.89682 0.19158 0.03938
# ['не', 'хотелось', 'бы', 'ошибиться'] -31.45231 0.0742 0.01667
# ['окей', 'спасибо'] -14.3713 0.03902 0.00793
# ['прошу', 'еще', 'ожидать', 'сотрудник', 'скоро', 'освободится'] -53.42559 0.04807 0.00893
# ['хорошо'] -6.02956 0.01451 0.0024
# ['я', 'переключаю', 'оставайтесь', 'в', 'чате'] -32.87337 0.19022 0.04777
# ['ок'] -6.39735 0.01066 0.00166
# ['здравствуйте'] -4.61557 0.04568 0.0098
# ['подождите', 'пожалуйста', 'я', 'ознакомлюсь', 'с', 'перепиской', '1', '1', 'минуты'] -50.92976 0.29825 0.0656
# ['добрый', 'день', 'вы', 'можете', 'прочитать', 'предыдущую', 'переписку', 'с', 'имя', 'но'] -70.09018 0.18803 0.03676
# ['вкратце', 'вопрос', 'такой'] -27.39081 0.0144 0.00214
# ['могут', 'ли', 'меня', 'в', 'три', 'прекрасный', 'день', 'отключить', 'от', 'до', 'а', 'затем', 'на', 'мою', 'жалобу', 'просто', 'говорить', 'не', 'разбираясь', 'в', 'сути', 'дела', '"увы', 'решение', 'пересмотру', 'не', 'подлежит', '"'] -229.7783 0.55715 0.13089
# ['переписка', 'большая', 'еще', 'пару', 'минут', 'пожалуйста'] -41.44966 0.12932 0.0259
# ['хорошр'] -13.28859 2e-05 0.0
# ['большое', 'спасибо', 'за', 'ожидание'] -24.5332 0.08083 0.01566
# ['имя', 'отчество', 'ваш', 'вопрос', 'и', 'беспокойство', 'я', 'понимаю', 'но', 'как', 'имя', 'неоднократно', 'писал', 'ограничение', 'дистанционного', 'обслуживания', 'действительно', 'возможно', 'в', 'данном', 'случае', 'к', 'сожалению', 'оно', 'произошло', 'из', 'за', 'технического', 'сбоя', 'потробвалось', 'некоторое', 'время', 'чтобы', 'разобраться', 'в', 'ситуации', 'и', 'устранить', 'неполадки'] -309.53315 0.60287 0.13412
# ['устранены', 'они', 'не', 'только', 'для', 'тех', 'кто', 'обратился', 'но', 'и', 'для', 'всех', 'клиентов', 'кто', 'попал', 'под', 'действие', 'данных', 'неполадок'] -158.64094 0.2222 0.04527
# ['специалисты', 'которые', 'послали', 'клиентов', 'до', 'того', 'как', 'разобрались', 'в', 'проблеме', 'уже', 'уволены', ';'] -112.769 0.18186 0.04245
# ['действительно', 'это', 'крайне', 'неприятная', 'ситуация'] -46.82542 0.02916 0.00521
# ['пока', 'нет', 'посмотрим', 'на', 'их', 'поведение'] -48.32545 0.11016 0.02407
# ['а', 'если', 'серьезно', 'еще', 'раз', 'извиняюсь', 'сработало', 'в', 'данном', 'случае', 'не', 'слишком', 'оперативное', 'обнаружение', 'проблемы'] -128.91242 0.29211 0.06792
# ['потому', 'сотрудники', 'видя', 'соответствующую', 'блокировку', 'и', 'информировали', 'о', 'невозможности', 'ее', 'снятия', 'так', 'как', 'в', 'случаях', 'отличных', 'от', 'сбоя', 'это', 'действительно', 'невозможно'] -180.52464 0.27687 0.06147
# ['я', 'конечно', 'всё', 'понимаю', 'могу', 'и', 'быть', 'сбор', 'и', 'человеческий', 'фактор', 'но', 'дайте', 'мне', 'совет', 'как', 'вести', 'себя', 'в', 'потенциально', 'возможной', 'как', 'я', 'сейчас', 'уже', 'понимаю', 'ситауции', 'когда'] -228.65269 0.548 0.12088
# ['когда', 'меня', 'внезапно', 'блокируют', 'а', 'я', 'зарубежом', 'например', 'а', 'затем', 'говорят', '"увы', 'решение', 'пересмотру', 'не', 'подлежит"'] -146.62872 0.21968 0.04676
# ['что', 'мне', 'тогда', 'делать'] -24.87612 0.07342 0.01381
# ['поднимать', 'шумиху', 'в', 'инете', 'и', 'сми'] -62.64592 0.15898 0.04109
# ['только', 'так', 'вопросы', 'решаются'] -30.20383 0.05284 0.0092
# ['блин', 'дурацкая', 'автокоррекция'] -40.29897 0.00021 2e-05
# ['имя', 'отчество', 'дайте', 'мне', 'пару', 'минут'] -39.45767 0.09431 0.01682
# ['а', 'тороплюсь', 'писать', 'и', 'не', 'проверяю', 'потому', 'что', 'тут', 'у', 'вас', 'слишком', 'короткий', 'тайм', 'аут'] -126.7721 0.2626 0.05564
# ['и', 'вы', 'вроде', 'не', 'видите', 'когда', 'клиент', 'набирает', 'сообщение'] -66.47624 0.1902 0.04142
# ['окей'] -9.53322 0.00069 7e-05
# ['имя', 'отчество', 'действительно', 'можем', 'не', 'видеть', 'когда', 'вы', 'пишете', 'это', 'касается', 'определенных', 'платформ', 'этот', 'вопрос', 'решается'] -131.31471 0.19225 0.03872
# ['и', 'кстати', 'каким', 'образом', 'вообще', 'возможно', 'отключение', 'от', 'до', 'если', 'суд', 'постановил', 'что', 'это', 'не', 'законно', 'да', 'я', 'слышал', 'что', 'банк', 'с', 'этим', 'не', 'согласен', 'и', 'будет', 'обжаловать', 'решение', 'но', 'разве', 'если', 'решение', 'суда', 'вступило', 'в', 'силу', 'банк', 'не', 'должен', 'ему', 'подчиняться'] -328.32209 0.89176 0.19544
# ['по', 'поводу', 'подобных', 'ситуаций', 'еще', 'раз', 'отмечу', 'что', 'такое', 'может', 'быть', 'по', '1', 'причинам', 'в', 'рамках', 'сбоя', 'тогда', 'вопрос', 'решается', 'достаточно', 'оперативно', 'так', 'как', 'вины', 'клиента', 'нет', 'второе', 'и', 'это', 'да', 'недавних', 'пор', 'было', 'единственной', 'причиной', 'действительно', 'подобный', 'сбой', 'у', 'нас', 'первый', 'и', 'будетм', 'надяться', 'в', 'последний', 'раз', 'ограничение', 'может', 'быть', 'введено', 'если', 'клиент', 'со', 'своей', 'стороны', 'нарушает', 'действующий', 'договор'] -493.6201 0.8805 0.19064
# ['получается', 'что', 'банк', 'действует', 'вопреки', 'решению', 'суда'] -66.79484 0.06733 0.01289
# ['назвать', 'точные', 'причины', 'по', 'конкретным', 'случаям', 'не', 'могу', 'по', 'причинам', 'конфиденциальности', 'но', 'поверьте', 'эти', 'причины', 'есть', 'в', 'качестве', 'примера', 'можно', 'привести', 'пункт', '1', '1', '1', 'общих', 'условий', 'открытия', 'ведения', 'и', 'закрытия', 'счетов', 'физических', 'лиц', 'а', 'также', 'выпуска', 'и', 'обслуживания', 'расчетных', 'карт'] -346.34689 0.6933 0.15531
# ['меня', 'на', 'самом', 'деле', 'больше', 'волнует', 'не', 'технический', 'сбой'] -73.90919 0.16159 0.0367
# ['банк', 'уже', 'обжалует', 'данное', 'решение'] -45.4031 0.03906 0.00683
# ['таким', 'образом', 'в', 'законную', 'силу', 'оно', 'не', 'вступило', 'суд', 'принял', 'решение', 'у', 'банка', 'есть', 'сроки', 'на', 'его', 'обжалование', 'банк', 'в', 'них', 'уложился', 'процесс', 'продолжается'] -205.19351 0.466 0.1119
# ['да', 'они', 'могут', 'иметь', 'место', 'особенно', 'когда', 'банк', 'улучшает', 'какие', 'то', 'алгоритмы', 'связанные', 'с', 'b', 'd', 'автоматизация', 'это', 'хорошо', 'но'] -172.39449 0.21587 0.03995
# ['пока', 'всё', 'работает', 'не', 'супер', 'отлажено', 'решения', 'так', 'или', 'иначе', 'принимают', 'люди'] -105.79982 0.11104 0.02262
# ['окончательное', 'да', 'вы', 'правы'] -31.47714 0.07668 0.01589
# ['и', 'тут', 'архиважным', 'является', 'то', 'какой', 'является', 'первоначальная', 'реакция', 'банка', 'на', 'обращения', 'и/или', 'жалобы', 'клиента'] -132.2753 0.1928 0.04113
# ['ваши', 'сотрудники', 'обязаны', 'быть', 'более', 'внимательными', 'если', 'они', 'заинтересованы', 'в', 'сохранении', 'доверия', 'к', 'банку', 'со', 'сторону', 'клиентов'] -153.81996 0.19762 0.04528
# ['как', 'только', 'стало', 'ясно', 'что', 'речь', 'идет', 'о', 'сбое', 'банк', 'оперативно', 'среагировал', 'на', 'ситауцию', 'действительно', 'с', 'вами', 'я', 'полностью', 'согласен', 'важно', 'именно', 'первое', 'обращение', 'в', 'том', 'числе', 'роль', 'в', 'устранении', 'сбоя', 'сыграло', 'и', 'информирование', 'со', 'стороны', 'клиентов'] -314.46255 0.61805 0.14251
# ['а', 'если', 'они', 'просто', 'глядят', 'что', 'им', 'выдает', 'база', 'данных', 'в', 'отношении', 'того', 'или', 'иного', 'клиента', 'и', 'затем', 'сразу', 'его', '"посылают"', 'по', 'совету', '"компьютера"'] -209.43111 0.37661 0.08323
# ['имя', 'отчество', 'это', 'издержки', 'работы', 'организации', 'имеющей', 'миллионы', 'клиентов'] -86.36795 0.05294 0.00892
# ['как', 'это', 'плохо', 'выглядит', 'с', 'точки', 'зрения', 'других', 'клиентов', 'а', 'в', 'современной', 'век', 'открытости', 'и', 'доступной', 'инфы', 'подобные', 'ситуации', 'раскрываются', 'очень', 'быстро', 'вам', 'ли', 'не', 'знать'] -232.21143 0.42139 0.09499
# ['не', 'надо', 'ссылаться', 'на', 'издержки', 'и', 'на', 'миллионы'] -65.16886 0.26642 0.0629
# ['работайте', 'над', 'персоналом', 'ёмаё', 'пока', 'он', 'играет', 'роль'] -91.39535 0.01337 0.00188
# ['миллионы', 'никакой', 'роли', 'не', 'играют', 'вы', 'не', 'самый', 'большой', 'банк', 'в', 'мире'] -106.02396 0.31059 0.07526
# ['действительно', 'информация', 'становится', 'открытой', 'и', 'банк', 'понес', 'репутационные', 'издержки', 'в', 'данной', 'ситуации', 'работа', 'виновных', 'в', 'данной', 'ситуации', 'несомненно', 'будет', 'оценена', 'по', 'достоинству'] -210.07486 0.38657 0.09399
# ['мы', 'действительно', 'не', 'самый', 'большой', 'банк', 'в', 'мире', 'однако', 'не', 'ошибается', 'тот', 'кто', 'ничего', 'не', 'делает', 'вопрос', 'только', 'в', 'том', 'насколько', 'оперативно', 'устранаются', 'последствия', 'таких', 'ошибок', 'и', 'появляются', 'ли', 'последствия', 'вообще'] -262.96041 0.56102 0.13277
# ['верно', 'равно', 'как', 'и', 'в', 'том', 'как', 'ответственные', 'даже', 'не', 'рядовые', 'сотрудники', 'относятся', 'к', 'клиентам', 'и', 'их', 'проблемам', 'в', 'общем', 'мне', 'в', 'целом', 'всё', 'понятно', 'спасибо', 'вам', 'за', 'ваше', 'время', 'и', 'ответы', 'для', 'себя', 'я', 'выводы', 'сделал'] -276.27828 0.89908 0.2088
# ['могу', 'лишь', 'сказать', 'что', 'теперь', 'я', 'не', 'так', 'доверяю', 'банку', 'как', 'раньше', 'но', 'в', 'этом', 'вряд', 'ли', 'есть', 'ваша', 'вина', 'имя'] -154.33931 0.41673 0.09216
# ['и', 'увы', 'советать', 'вас', 'кому', 'либо', 'с', 'чистой', 'совестью', 'вряд', 'ли', 'смогу', 'в', 'ближайшее', 'время'] -129.87459 0.27313 0.06284
# ['а', 'так', 'буду', 'следить', 'за', 'новостями', ';'] -56.17298 0.0794 0.01463
# ['имя', 'отчество', 'ваши', 'выводы', 'мне', 'ясны', 'я', 'могу', 'со', 'своей', 'стороны', 'заверить', 'вас', 'что', 'подобные', 'ситуации', 'действительно', 'единичны', 'и', 'оперативно', 'устраняются', 'данная', 'получилась', 'достаточно', 'резонансной', 'но', 'поверьте', 'в', 'любой', 'ситуации', 'банк', 'отличает', 'сбой', 'от', 'верных', 'причин', 'и', 'решает', 'проблемы', 'оперативно'] -361.16952 0.52102 0.11232
# ['честно', 'говоря', 'не', 'знаю', 'зачем', 'я', 'обратился', 'в', 'чат', 'и', 'чего', 'я', 'ждал'] -98.13946 0.36945 0.08968
# ['ну', 'буду', 'надеяться', 'что', 'это', 'действительно', 'так'] -52.08286 0.0841 0.01543
# ['я', 'на', 'самом', 'деле', 'понимаю', 'причины', 'по', 'которым', 'вы', 'обратились', 'действительно', 'неприятно', 'попасть', 'в', 'такую', 'ситуацию', 'и', 'хочется', 'себя', 'обезопасить'] -164.13358 0.41074 0.09816
# ['от', 'себя', 'могу', 'пожелать', 'сотрудникам', 'банка', 'большей', 'внимательность', 'чуткости', 'и', 'человечности', 'они', 'очень', 'важны', 'в', 'бизнес', 'модели', 'банка', '11', 'века'] -193.25151 0.31422 0.07128
# ['имя', 'отчество', 'перед', 'вами', 'сейчас', 'стоит', '1', 'примера', '1', 'сбой', 'который', 'вас', 'не', 'затронул', 'о', 'ситуации', 'вы', 'знаете', 'насколько', 'я', 'понял', 'только', 'от', '1', 'их', 'лиц', '1', 'опыт', 'личного', 'общения', 'ит', 'взаимодействия', 'с', 'банком'] -261.63198 0.63543 0.13498
# ['скажите', 'пожалуйста', 'что', 'из', 'этого', 'все', 'же', 'перевешивает'] -58.54551 0.12624 0.02404
# ['дело', 'не', 'только', 'в', 'этом'] -29.43391 0.19197 0.04774
# ['и'] -4.39216 0.05435 0.01222
# ['просто', 'последнее', 'время', 'достаточно', 'не', 'очень', 'приятных', '"мелочей"'] -70.59667 0.09235 0.01935
# ['ну', 'а', 'это', 'ситуация', 'в', 'который', 'оказались', 'нормальные', 'клиенты', 'на', 'месте', 'который', 'мог', 'бы', 'легко', 'оказаться', 'и', 'я', 'просто', 'резко', 'перепронила', 'чашу'] -194.74483 0.38194 0.08871
# ['почему', 'то', 'всё', 'чаще', 'стало', 'хотеться', 'ставить', 'вам', 'в', 'пример', 'рокетбанк'] -99.7355 0.19091 0.04586
# ['имя', 'отчество', 'просто', 'как', 'пример', '11', '11', '1111', 'года', 'тоже', 'пострадало', 'достаточное', 'количество', 'нормальных', 'клиентов', 'причем', 'действительно', 'понесло', 'серьезные', 'потери', 'а', 'началось', 'все', 'с', 'технической', 'причины', 'в', 'нашей', 'же', 'ситации', 'безвозвратных', 'потерь', 'не', 'произошло', 'и', 'слава', 'богу'] -339.78705 0.53015 0.11744
# ['точнее', 'конкретно', 'их', 'взаимодействие', 'с', 'клиентами'] -56.39206 0.05326 0.01082
# ['то', 'как', 'они', 'это', 'делают'] -33.79497 0.09524 0.01788
# ['ммм', 'я', 'крайне', 'надеюсь', 'что', 'вы', 'не', 'про', 'пример', 'с', 'изъятием', 'вкладов', 'в', 'интеркоммерце'] -113.87048 0.3716 0.08835
# ['тоже', 'не', 'без', 'косяков', 'конечно'] -40.16442 0.07987 0.01742
# ['не', 'я', 'не', 'про', 'интеркоммерц', 'у', 'которого', 'знаю', 'что', 'отозвали', 'лицензию'] -89.91352 0.27476 0.06193
# ['мне', 'кстати', 'асв', 'уже', 'вернули', 'оттуда', 'денюжку'] -70.34042 0.0374 0.00656
# ['это', 'опять', 'же', 'как', 'пример', 'того', 'что', 'не', 'ошибается', 'тот', 'кто', 'ничего', 'не', 'делает'] -107.83179 0.24164 0.05131
# ['на', 'новую', 'карту', 'открытия', 'которую', 'мне', 'бесплатно', 'доставили', 'в', 'тай', 'курьером'] -90.30615 0.23161 0.05606
# ['я', 'не', 'о', 'банке'] -20.19396 0.16191 0.03624
# ['я', 'тоже'] -11.73037 0.06979 0.01618
# ['а', 'о', 'конкретно', 'клиентской', 'поддержке'] -45.72159 0.04413 0.00798
# ['просто', 'это', 'мой', 'личный', '"юзер', 'экспириенс"', 'так', 'сказать'] -75.37163 0.04959 0.00832
# ['общение', 'с', 'поддержкой', 'тинькоффа', 'и', 'рокета'] -57.88436 0.10037 0.02205
# ['имя', 'отчество', 'давайте', 'мы', 'с', 'вами', 'если', 'позволите', 'перейдем', 'к', 'более', 'предметному', 'разговору', 'если', 'речь', 'идет', 'о', 'клиентской', 'поддержке', 'то', 'напишите', 'пожалуйста', 'в', 'чем', 'именно', 'у', 'вас', 'остался', '"осадок"', 'после', 'общения', 'с', 'нами'] -268.56002 0.56191 0.11771
# ['раньше', 'я', 'не', 'видел', 'разницы', 'рокет', 'был', 'просто', 'забавным'] -78.59709 0.15009 0.03383
# ['сейчас', 'вижу'] -11.62441 0.03846 0.00693
# ['это', 'сложно', 'выразить', 'каким', 'то', 'одним', 'конкретным', 'примером', 'или', 'двумя', 'большинство', 'сотрудников', 'поддержки', 'и', 'кц', 'почти', 'всех', 'банков', 'отвечают', 'как', 'роботы'] -202.54263 0.16829 0.03314
# ['к', 'сожалению', 'тинькофф', 'в', 'этом', 'отношении', 'не', 'далеко', 'ушёл', 'он', 'конечно', 'лучше', 'многих', 'но', 'всё', 'ж'] -129.60746 0.23505 0.05427
# ['конкретно', 'этот', 'чат', 'технически', 'не', 'доработан', 'ну', 'я', 'уже', 'говорил', 'об', 'этом', 'писал', 'тут', 'раньше', 'несколько', 'дней', 'или', 'недель', 'назад'] -158.70172 0.22498 0.04558
# ['просто', 'если', 'рассматривать', 'сбои', 'и', 'массовые', 'проблемы', 'то', 'они', 'имеют', 'место', 'во', 'всех', 'организациях', 'равно', 'как', 'и', 'реакция', 'на', 'данные', 'ситуации', 'кто', 'то', 'с', 'ними', 'сталкивается', 'кого', 'то', 'они', 'не', 'затрагивают', 'относительно', 'общения', 'полностью', 'с', 'вами', 'согласен', 'есть', 'куда', 'расти', 'и', 'мы', 'растем', 'растим', 'профессионалов', 'как', 'среди', 'сотрудников', 'кц', 'так', 'и', 'среди', 'наших', 'секторов'] -481.35691 0.74458 0.15557
# ['слишком', 'быстро', 'сбрасывают', 'клиента', 'пока', 'он', 'набирает', 'сообщение', 'понимаю', 'регламент', 'но', 'это', 'кривой', 'регламент'] -137.58843 0.07022 0.01149
# ['это', 'замечательно'] -16.17299 0.0261 0.00486
# ['я', 'просто', 'как', 'клиент', 'и', 'говорю', 'что', 'именно', 'и', 'конкретно', 'во', 'взаимодействии', 'с', 'клиентом', 'хочется', 'ставить', 'вам', 'в', 'пример', 'рокет', 'который', 'тоже', 'не', 'идеален', 'но', 'ведь', 'нет', 'в', 'мире', 'совершенства'] -242.66321 0.67419 0.15674
# ['кстати', 'очень', 'круто', 'что', 'тинькофф', 'вообще', 'чат', 'добавил', 'в', 'приложение'] -78.73537 0.16322 0.03929
# ['чату', 'нашему', 'тоже', 'не', 'столь', 'много', 'времени', 'сейчас', 'тестируем', 'режимы', 'регламенты', 'меняем', 'поверьте', 'сейчас', 'справа', 'от', 'меня', 'висит', 'регламент', 'о', 'котором', 'еще', 'несколько', 'недель', 'наз', 'даже', 'не', 'думали', 'постоянный', 'рост', 'несомненно', 'рождает', 'и', 'проблемы', 'роста', 'но', 'мы', 'с', 'ними', 'справимся'] -380.50834 0.43793 0.08952
# ['видимо', 'глядя', 'на', 'рокет', ';'] -48.23964 0.07364 0.01762
# ['назад'] -8.44934 0.00181 0.00021
# ['я', 'бы', 'сказал', 'нет', 'но', 'вы', 'же', 'не', 'поверите'] -61.59968 0.23772 0.05159
# ['хехехе'] -15.36803 0.0 0.0
# ['вообще', 'конечно', 'хочется', 'пожелать', 'успеха', 'банку'] -64.28139 0.00747 0.00092
# ['и', 'может', 'даже', 'как', 'то', 'помочь', 'что', 'ли'] -46.03522 0.19936 0.03941
# ['не', 'только', 'для', 'себя', 'или', 'для', 'банка'] -41.2142 0.17373 0.03496
# ['ведь', 'если', 'банк', 'станет', 'лучше', 'другие', 'будут', 'брать', 'пример', 'а', 'здоровая', 'конкуренция', 'это', 'всегда', 'хорошо', 'и', 'развитие'] -145.39916 0.21972 0.04282
# ['мы', 'всегда', 'открыты', 'для', 'предложений', 'имя', 'отчество', 'если', 'у', 'вас', 'будут', 'интересные', 'идеи', 'пишите'] -106.99334 0.21922 0.04111
# ['насчет', 'примера', 'уже', 'берут', 'как', 'ни', 'крути'] -67.72338 0.04333 0.00775
# ['и', 'в', 'итоге', 'всем', 'клиентам', 'станет', 'лучше'] -55.25459 0.16326 0.04156
# ['и', 'банку', 'потому', 'что', 'к', 'нему', 'пойдут', 'новые', 'клиенты'] -72.90017 0.1136 0.02321
# ['а', 'как', 'собственно', 'я', 'могу', 'писать', 'о', 'предожениях', 'замечаниях', 'и', 'своём', 'ux', 'надеясь', 'что', 'помогаю', 'банку', 'напрямую', 'ответственным', 'за', 'это', 'сотрудникам', 'минуя', '"роботов"', 'и', 'рядовых', 'специалистов'] -252.70838 0.37508 0.07836
# ['по', 'моему', 'опыту', 'не', 'все', 'из', 'них', 'заинтересованы', 'в', 'развитии', 'своей', 'компании', 'и', 'пожелания', 'клиентов', '"наверх"', 'не', 'передают'] -156.46969 0.37242 0.08825
# ['поверьте', 'то', 'что', 'вы', 'доносите', '"роботам"', 'в', 'любом', 'случае', 'доходит', 'до', 'того', 'кому', 'оно', 'предназначено', 'если', 'не', 'доходит', 'это', 'вина', 'конкретного', 'сотрудника', 'и', 'банк', 'будет', 'решать', 'вопрос', 'о', 'его', 'компетентности'] -254.5952 0.53593 0.11622
# ['ну', 'окей'] -17.27128 0.00406 0.00051
# ['вы', 'можете', 'отправлять', 'ваши', 'предложения', 'как', 'в', 'наши', 'группы', 'с', 'соцсетях', 'так', 'и', 'в', 'чат', 'можно', 'позвонить', 'или', 'написать', 'е', 'мейл', 'как', 'вам', 'удобно', 'мы', 'действительно', 'очень', 'ценим', 'ваше', 'стремление', 'недавние', 'награды', 'как', 'раз', 'в', 'соцсетях', 'это', 'доказали'] -303.28759 0.76841 0.17451
# ['награждения'] -15.36803 0.0 0.0
# ['не', 'в', 'курсе', 'о', 'награждениях', 'ну', 'да', 'ладно', 'кстати', 'пока', 'вспомнил', 'последние', 'пару', 'недель', 'приложение', 'гораздо', 'чаще', 'стало', 'тормозить', 'и', 'вылетать'] -187.9045 0.30076 0.06917
# ['в', 'какой', 'конкретно', 'момент', 'это', 'началось', 'сказать', 'не', 'могу'] -63.64931 0.23991 0.05677
# ['можете', 'дать', 'кртакую', 'информацию', 'версия', 'ос', 'версия', 'приложения', 'устройство'] -81.08172 0.05865 0.01041
# ['я', 'передам', 'коллегам', 'посмотяр', 'возможные', 'причины'] -54.19269 0.07699 0.01718
# ['посмотрят'] -11.75712 9e-05 1e-05
# ['вход', 'в', 'инет', 'банк', 'через', 'веб', 'интерфейс', 'тоже', 'тормозит', 'и', 'глючит', 'последние', 'несколько', 'недель', 'сначала', 'списывал', 'это', 'на', 'не', 'очень', 'быстрый', 'тайский', 'инет', 'но', 'ведь', 'всякие', 'другие', 'инет', 'банки', 'у', 'меня', 'шустрее', 'тут', 'работают'] -298.58183 0.4613 0.10298
# ['сейчас', 'кину', 'скриншоты'] -27.84257 0.02817 0.00529
# ['a', 'p', 's', 'a', '1', '1', '1'] -46.9156 0.18145 0.0408
# ['могу', 'ещё', 'на', '1', 'андроид', '1', '1', 'попробовать', 'на', 'нём', 'просто', 'пока', 'нет', 'приложения'] -92.76438 0.39484 0.0883
# ['ещё', 'такое', 'замечание', 'по', 'приложению', 'когда', 'спустя', 'время', 'запускаешь', 'его', 'вновь', 'вводишь', 'код', 'доступа', 'попадаешь', 'в', 'раздел', 'в', 'котором', 'был', 'в', 'последний', 'раз'] -192.02908 0.43512 0.1084
# ['информацию', 'я', 'коллегам', 'передал', 'они', 'посмотрят', 'и', 'проинформируют', 'вас', 'в', 'течение', '1', 'календарного', 'дня', 'sms', 'сообщением', 'или', 'звонком', 'отслеживать', 'статус', 'обращения', 'вы', 'можете', 'в', 'интернет', 'банке', 'в', 'разделе', '«связь', 'с', 'банком»', 'или', 'в', 'приложении'] -214.35142 0.93665 0.21877
# ['и', 'когда', 'в', 'этом', 'разделе', 'нажимаешь', 'клавишу', '"назад"', 'чтоб', 'выйти', 'в', 'меню', 'приложения', 'или', 'на', 'его', 'главный', 'экран', 'вместо', 'этого', 'вообще', 'происходит', 'выход', 'из', 'приложения', 'и', 'приходится', 'заново', 'входить'] -241.91696 0.47001 0.11161
# ['это', 'происходит', 'почти', 'всегда', 'и', 'иногда', 'раздражает'] -56.40993 0.09794 0.01976
# ['а', 'вот', 'этот', 'момент', 'сам', 'замечал', 'добавлю', 'ваш', '1'] -71.56317 0.11016 0.022
# ['по', 'поводу', 'смс', 'или', 'звонка', 'в', 'этом', 'смысла', 'нет', 'симкой', 'российской', 'не', 'пользуюсь'] -100.19447 0.28652 0.06693
# ['так', 'как', 'за', 'рубежом'] -27.58785 0.07529 0.01426
# ['напишу', 'чтобы', 'по', 'е', 'мейл', 'ответили', 'подойдет'] -54.12517 0.07833 0.01564
# ['да', 'отлично'] -13.95096 0.02881 0.00534
# ['кстати', 'пуш', 'уведомления', 'приходят', 'очень', 'выборочно', 'хотя', 'включены'] -78.03122 0.00935 0.00111
# ['около', '11%', 'пушей', 'продолжают', 'приходить', 'смсками'] -65.67612 0.00418 0.00048
# ['в', 'смысле', '11%', 'уведомлений', 'и', 'кодов', 'подтверждения', 'операций'] -62.79574 0.17001 0.04251
# ['вместо', 'пуш', 'приходят', 'смс'] -34.95629 0.01037 0.00143
# ['пока', 'что', 'в', 'виде', 'sms', 'по', 'прежнему', 'приходят', 'коды', 'если', 'вы', 'совершаете', 'операцию', 'в', 'интернете', 'увежомлениями', 'отправляются', 'только', 'коды', 'для', 'мобильного', 'приложения'] -166.25088 0.46286 0.1082
# ['уведомлениями'] -12.59545 4e-05 0.0
# ['вот', 'тут', 'в', 'чате', 'пытаюсь', 'посмотреть', 'переписку', 'выше', 'но', 'меня', 'всё', 'время', 'кидает', 'в', 'самый', 'низ', 'когда', 'вы', 'что', 'то', 'набираете', 'не', 'удобно', 'и', 'менее', 'спокойного', 'человека', 'начало', 'бы', 'бесить'] -241.62104 0.54557 0.12484
# ['ясно', 'ладно'] -17.05158 0.00387 0.00047
# ['ну', 'касаемо', 'не', 'очень', 'приятных', 'изменений', 'в', 'тарифах', 'это', 'совсем', 'из', 'другой', 'оперы', 'думаю', 'смысла', 'нет'] -136.89535 0.24347 0.05688
# ['по', 'поводу', 'перекидывания', 'на', 'самом', 'деле', 'это', 'для', 'удобства', 'чтобы', 'вам', 'не', 'скроллить', 'вниз', 'передам', 'коллегам', 'как', 'пожелание', 'пусть', 'подумают', 'что', 'можно', 'сделать'] -185.8564 0.40812 0.08579
# ['посмотреть', 'как', 'это', 'сделано', 'в', 'том', 'же', 'телеграме', 'например'] -69.42595 0.18154 0.04242
# ['просто', 'появляется', 'значок', 'возврата', 'в', 'самый', 'низ'] -61.02151 0.1145 0.03017
# ['такое', 'автоперекидывание', 'вниз', 'совсем', 'не', 'удобно'] -54.31271 0.07337 0.01641
# ['тарифы', 'ну', 'на', 'самом', 'деле', 'задевает', 'в', 'основном', 'тех', 'у', 'кого', 'нет', 'вкладов', 'и', 'кто', 'не', 'хочет', 'пользоваться', 'картой', 'по', 'сути', 'банк', 'разграничивает', 'продукты', 'есть', 'вклады', 'накопительные', 'счета', 'для', 'сохранения', 'а', 'есть', 'карта', 'для', 'использвания', 'средств'] -297.2426 0.5978 0.13054
# ['а', 'есть', 'ещё', 'кредитная', 'карта', 'которой', 'в', 'основном', 'и', 'пользуешься'] -73.4803 0.22336 0.0521
# [] 0 0 0
# ['а', 'сейчас', 'получается', 'придется', 'пользоваться', 'дебетовой'] -44.23844 0.06596 0.01193
# ['что', 'не', 'очень', 'интересно', 'или', 'выводить', 'с', 'неё', 'все', 'средства'] -71.59678 0.19457 0.04034
# ['как', 'будто', 'банку', 'не', 'нужны', 'деньги', 'впрочем', 'думаю', 'специалисты', 'всё', 'рассчитали', 'и', 'много', 'банк', 'от', 'этого', 'не', 'потеряет', 'отток', 'средств', 'с', 'карт', 'вряд', 'ли', 'будет', 'большой'] -211.37329 0.37864 0.07856
# ['тут', 'уже', 'не', 'в', 'моей', 'компетенции', 'обсуждать', 'или', 'осуждать', 'данные', 'нововведения', 'думаю', 'вы', 'понимаете', 'несоменно', 'перед', 'введением', 'аналитики', 'производили', 'расчеты'] -194.03277 0.26333 0.06188
# ['мне', 'советовали', 'открывать', 'накопительный', 'счёт', 'но', 'это', 'менее', 'удобно', 'нежели', '%', 'на', 'остаток', 'по', 'карте', 'к', 'тому', 'же', 'там', 'ставка', 'не', 'очень', 'в', 'сравнении', 'с', 'другими', 'банками', 'ну', 'тут', 'ладно', 'это', 'другой', 'вопрос', 'в', 'банке', 'думаю', 'всё', 'рассчитали'] -292.57946 0.65213 0.1465
# ['ну', 'да', 'я', 'об', 'этом', 'и', 'говорю'] -46.27991 0.16222 0.03505
# ['ну', 'да', 'ставка', 'там', 'на', '1%', 'пониже', 'зато', 'нет', 'платы', 'за', 'обслуживание', 'нет', 'каких', 'либо', 'минимальных', 'сумм'] -136.39731 0.21751 0.04347
# ['а', 'какой', 'кстати', 'должен', 'быть', 'там', 'минимальный', 'остаток', 'чтоб', 'за', 'обслуживание', 'белковой', 'карты', 'не', 'описывали'] -117.58444 0.19086 0.03741
# ['белковой'] -13.98174 1e-05 0.0
# ['белковой'] -13.98174 1e-05 0.0
# ['дебетовой'] -7.57775 0.00388 0.00051
# ['не', 'списывали'] -15.94665 0.06491 0.01534
# ['11', '111', 'руб', 'неснижаемый'] -27.65455 0.09962 0.02077
# ['а', 'ну', 'тоже', 'самое', 'как', 'и', 'на', 'карте', 'а', 'если', 'депозит', 'в', 'смысле', 'вклад', 'тогда', 'от', '11', 'т'] -114.77153 0.48094 0.10709
# ['так', 'я', 'про', 'карту', 'и', 'говорил', 'наверное', 'неправильно', 'вас', 'понял', 'накопительные', 'счета', 'никак', 'не', 'влияют', 'на', 'списание', 'платы', 'за', 'обслуживание'] -144.81958 0.38986 0.08441
# ['кстати', 'в', 'чате', 'отражается', 'время', 'сообщений', 'по', 'москве'] -59.50587 0.18643 0.04531
# ['а', 'тут', 'у', 'меня', 'например', 'уже', '11', '11'] -46.80808 0.21237 0.04416
# ['а', 'в', 'чате', 'время', 'сообщений', '11', '11'] -39.2812 0.27493 0.0649
# ['мелочь', 'но', 'не', 'совсем', 'корректно', 'всё', 'ж'] -58.83623 0.08678 0.01868
# ['а', 'получается', 'если', 'я', 'с', 'карты', 'переведу', 'почти', 'всё', 'на', 'накопительный', '11р', 'по', 'карте', 'всё', 'равно', 'будет', 'ежемесячно', 'списываться'] -134.84682 0.38715 0.08282
# ['тогда', 'ещё', 'менее', 'удобно', 'и', 'менее', 'выгодно'] -53.13833 0.07885 0.01564
# ['да', 'время', 'берется', 'московское', 'так', 'на', 'самом', 'деле', 'удобнее', 'при', 'повторных', 'обращениях', 'по', 'ранним', 'чатам', 'определять', 'о', 'каком', 'именно', 'сообщении', 'идет', 'речь', 'к', 'примеру', 'вы', 'будете', 'недовольны', 'мой', 'фразой', 'сказанной', 'к', 'примеру', 'в', '11', '11', 'но', 'ваши', '11', '11', 'и', '11', '11', 'банка', 'разные', '11', '11', 'потому', 'может', 'произойти', 'недопонимание'] -410.23584 0.97666 0.21618
# ['плату', 'за', 'обслуживание', 'по', 'расчетной', 'карет', 'мы', 'не', 'списываем', 'если', 'на', 'ней', 'нет', 'средств', 'вообще'] -106.59292 0.32703 0.07037
# ['карте'] -5.85198 0.01682 0.00287
# ['не', 'совсем', 'конечно', 'понятно', 'зачем', 'клиента', 'заставлять', 'тратить', '1', 'тысячи', 'по', 'дебетовой', 'если', 'он', 'использует', 'в', 'основном', 'только'] -141.56373 0.36123 0.08369
# ['а', 'ну', 'да', 'своя', 'логика', 'в', 'этом', 'есть', 'с', 'часовым', 'поясом', 'хотя', 'может', 'и', 'можно', 'это', 'как', 'то', 'улучшить', 'например', 'запрашивать', 'у', 'приложения', 'часовой', 'пояс', 'клиента', 'и', 'затем', 'корректировать', 'время', 'сообщений', 'на', 'сервере', 'ну', 'или', 'как', 'то', 'так'] -304.90263 0.68383 0.14494
# ['ну', 'если', 'средств', 'на', 'карте', 'нет', 'это', 'да', 'понятно', 'хотя', 'совсем', 'всё', 'с', 'карты', 'выводить', 'не', 'хочется'] -113.25882 0.36698 0.07654
# ['хм', 'в', 'этом', 'случае', 'ваши', '11', '11', 'все', 'еще', 'отличаются', 'от', 'моих', '11', '11', 'по', 'поводу', 'списания', 'можно', 'ведь', 'держать', '11', '111', 'руб', 'на', 'карте', 'или', 'открыть', 'вклад'] -184.86591 0.71253 0.15789
# ['да', 'но', 'тогда', 'не', 'будут', '%', 'начисляться', 'если', 'не', 'тратить', '1', 'тыщи', 'по', 'дебетовой'] -93.99549 0.35299 0.07624
# ['странно', 'что', 'расходов', 'по', 'кредитной', 'не', 'достаточно'] -46.96571 0.16914 0.03668
# ['вклад', 'отдельная', 'тема', 'мне', 'пока', 'не', 'очень', 'удобная'] -67.66691 0.10516 0.02214
# ['это', 'да', 'верно', 'ну', 'а', 'расходы', 'по', 'кредитной', 'карте', 'все', 'же', 'расходы', 'по', 'абсолютно', 'иному', 'продукту'] -121.58707 0.24439 0.04799
# ['ясно', 'но', 'можно', 'было', 'бы', 'и', 'объединить', 'в', 'смысле', 'смотреть', 'в', 'целом', 'активность', 'клиента', 'по', 'всем', 'картам', 'и', 'потом', 'уже', 'решать', 'начислять', 'проценты', 'на', 'остаток', 'или', 'нет', 'ну', 'банку', 'вмднее'] -233.68695 0.57687 0.13323
# ['ну', 'в', 'общем', 'ладно', 'спасибо', 'вам', 'за', 'беседу', 'надеюсь', 'как', 'то', 'помогаю', 'становиться', 'банку', 'лучше'] -121.05686 0.29042 0.0656
# ['действительно', 'помогаете', 'рад', 'был', 'общению', 'если', 'появятся', 'вопросы', 'обращайтесь'] -66.99095 0.10883 0.01973
# ['хорошо', 'спасибо', 'всего', 'доброго'] -21.35534 0.10827 0.02078
# ['хорошего', 'вам', 'дня', 'хотя', 'у', 'вас', 'уже', 'скорее', '"хорошего', 'вечера"'] -82.13644 0.14969 0.02904
# ['да'] -5.25875 0.02735 0.00517
# ['кстати', 'ещё', 'совет'] -28.47713 0.00749 0.00105
# ['пока', 'помню'] -15.99417 0.00728 0.001
# ['да', 'какой'] -12.03486 0.03508 0.00631
# ['можно', 'было', 'бы', 'сюда', 'в', 'чат', 'добавить', 'голосовые', 'сообщения', 'как', 'в', 'мессенджерах'] -94.71204 0.28603 0.07085
# ['не', 'всегда', 'удобно', 'набирать', 'длинный', 'текст'] -53.41399 0.08331 0.01819
# ['да', 'и', 'эмоции', 'и', 'интонации', 'клиента', 'лучше', 'понятны', 'из', 'голоса', 'нежели', 'чем', 'из', 'текста'] -128.72731 0.17494 0.03573
# ['вы', 'имеете', 'ввиду', 'голосовые', 'сообщения', 'или', 'голосовой', 'набор'] -76.04005 0.07439 0.01485
# ['сообщения', 'голосом', 'нажал', 'кнопку', 'наговорил', 'сообщение', 'отпустил', 'кнопку', 'сообщение', 'в', 'виде', 'аудио', 'отправилось', 'в', 'банк'] -141.18643 0.26001 0.06612
# ['понял', 'о', 'чем', 'вы'] -23.15354 0.08891 0.0173
# ['голосовой', 'набор', 'это', 'и', 'так', 'есть', 'в', 'андроиде', 'да', 'и', 'в', 'айос', 'вроде', 'уже', 'тоже'] -113.31212 0.41692 0.09949
# ['основной', 'минус', 'поиск', 'по', 'ним', 'не', 'работает'] -54.89488 0.12331 0.0278
# ['но', 'ведь', 'можно', 'просто', 'позвонить', 'из', 'приложения', 'впрочем', 'суть', 'вашего', 'предложения', 'понятна', 'коллегам', 'на', 'рассмотрение', 'тоже', 'отправлю'] -141.16501 0.14254 0.02825
# ['а', 'кстати', 'тут', 'в', 'чате', 'и', 'так', 'поиска', 'нет', 'у', 'клиента', 'тоже', 'можно', 'было', 'бы', 'добавить'] -109.0346 0.32449 0.07065
# ['есть', 'еще', '1', 'минус', 'может', 'получиться', 'так', 'что', 'устная', 'речь', 'банкально', 'будет', 'невнятной', '/', 'неясной'] -133.40478 0.21448 0.04232
# ['звонить', 'не', 'всегда', 'удобно'] -27.34343 0.08345 0.01821
# ['банально'] -13.42212 2e-05 0.0
# ['и', 'не', 'всегда', 'скорость', 'инета', 'для', 'этого', 'достаточна'] -67.85035 0.16688 0.0359
# ['ну', 'так', 'она', 'и', 'при', 'звонке', 'тогда', 'такой', 'же', 'будет'] -68.35455 0.14089 0.02653
# ['верно', 'зато', 'письменно', 'получается', 'лучше'] -48.09768 0.01083 0.00145
# ['ну', 'тоже', 'когда', 'как'] -27.06758 0.04614 0.00808
# ['не', 'спорю', 'случаи', 'бывают', 'разные'] -48.42874 0.06623 0.01548
# ['и', 'главное', 'не', 'понятны', 'интонации', 'и', 'эмоции', 'клиента'] -70.74843 0.17615 0.04007
# ['ну', 'это', 'просто', 'думаю', 'удобная', 'для', 'клиента', 'опция', 'а', 'ваши', 'спецы', 'уже', 'сами', 'решат', 'стоит', 'ли', 'она', 'того', 'или', 'нет'] -160.29236 0.17906 0.03118
# ['большинство', 'наверное', 'всё', 'равно', 'будут', 'текст', 'набирать', 'по', 'крайней', 'мере', 'первое', 'время'] -111.36017 0.07854 0.01555
# ['сложность', 'ещё', 'и', 'в', 'хранении', 'всех', 'этих', 'аудио', 'ну', 'и', 'траффик'] -99.36674 0.22607 0.05502
# ['к', 'слову', 'от', 'траффике', 'передача', 'то', 'тоже', 'за', 'ваш', 'счет', 'будет'] -88.22824 0.14975 0.02729
# ['да', 'для', 'клиента', 'это', 'мизер', 'тем', 'более', 'когда', 'инет', 'анлимит', 'или', 'большие', 'пакеты', 'а', 'вот', 'банку', 'на', 'кучу', 'клиентов', 'да', 'чуть', 'больше', 'расходов'] -197.84245 0.261 0.05123
# ['а', 'значит', 'и', 'выше', 'себестоимость', 'услуг'] -49.42539 0.08993 0.01853
# ['впрочем', 'не', 'знаю', 'может', 'в', 'сравнении', 'с', 'другими', 'расходами', 'тоже', 'не', 'большая', 'разница'] -108.82533 0.29725 0.0718
# ['ладно', 'ещё', 'раз', 'вам', 'всего', 'доброго', 'и', 'приятных', 'выходных', 'приятно', 'пообщаться', 'с', 'адекватным', 'сотрудником', 'банка', 'таким', 'как', 'вы', 'имя'] -148.79232 0.32772 0.06623
# ['всего', 'доброго', 'вам', 'имя', 'отчество'] -27.815 0.12276 0.02364
# ['эмодзи', 'ещё', 'добавьте'] -33.87529 0.00693 0.00099
# ['иногда', 'их', 'не', 'хватает'] -30.84022 0.0723 0.01635
# ['я', 'серьёзно'] -17.42788 0.06598 0.01568
# ['такое', 'предложение', 'уже', 'есть', 'действительно', 'их', 'не', 'хватает', 'приходится', 'выдумывать', 'что', 'то', 'из', 'знаков', 'препинания'] -130.68412 0.1792 0.03599
# ['общение', 'будет', 'более', 'человечное'] -38.89778 0.03245 0.00587
# ['ага', ';'] -18.20574 0.00204 0.00022
# ['ладно', 'я', 'побежал', 'удачи', 'вам', 'имя'] -48.176 0.12542 0.02752
# ['ну', 'и', 'банку', 'тоже'] -28.47327 0.06294 0.01332
# ['до', 'свидания'] -11.9623 0.03428 0.00606

# %%
for line in chats[16622]:
    print(" ".join(line))
# Out:
# добрый день узнал тут о "техническом сбое" который вроде как был в банке пару дней назад из за которого обычным нормальным клиентам заблокировали дистанционное обслуживание сижу вот теперь в небольшом шоке и честно говоря несколько нарушен ситуацией как вообще такое могло произойти и какие теперь гарантии что подобное не произойдёт и со мной надеюсь на ответ старшего специалиста
# здравствуйте
# упс не нарушен а напуган
# последствия сбоя были оперативно устранены ограничение дистанционного обслуживание мы вводим только при наличии на то оснований
# и всё
# во первых не так уж и оперативно были они устранены давайте будем объективными
# имя отчество банк имеет право ограничить дистанционное обслуживание информация об этом есть в er<j/
# укбо
# во вторых представители банка вообще говорили что решения принята на основании каких то пунктов условий обслуживания которые суд уже признал незаконными
# и затем "увы решение пересмотру не подлежит "
# это как вообще
# это вот такое отношения банка к лояльным клиентам
# банк не согласен с решением суда и будет его оспаривать повторюсь банк ограничивает дистанционное обслуживание при наличии на то причин
# а потом внезапно это оказалось техническим сбоем
# окей оспаривает но решения суда и банк обязан исполнять насколько я знаю но вопрос не в этом
# если говорить про сбой то он затронул несколько клиентов все остальные случаи вынужденная мера которой банк воспользовался
# несколько только лишь несколько клиентов отписались об этом на форуме и в соц сетях
# вы хотите сказать что все эти "несколько клиентов" знают что такое и могут написать отзыв
# просто вы ознакомились с ситуацией других клиентов из сми или других источников возможно по описанию в статьях она кажется абсурдной но банк не огарничивает обслуживание без наличия на то веских причин
# в одном месте написано представители говорят о "несколько десятков" вы о "нескольких клиентах"
# погодите
# я лишь сказал что сбой о ктором вы пишите распространился на сравнительно небольшое количество клиентов клиентов которым банк ограничил обслуживание вне сбоя больше
# котором
# сначала банк в лице представителя пишет "увы решение пересмотру не подлежит "
# потом о техническом сбое одному и тому же клиенту
# я этого вообще не понимаю
# я не могу комментировать какую либо ситуацию по конкретному клиенту если вы им не являетесь мне неизвестна причина по которой клиенту предоставили такую информацию
# меня не интересуют клиенты которые действительно что то химичат
# я речь веду у нормальных клиентах к которым и отношусь
# какие у меня теперь могут быть гарантии что меня условно завтра так же не отключат без объяснения причин и скажут "увы решение пересмотру не подлежит "
# хотя это окажется каким то очередным "техническим сбоем"
# у нас большинство именно таких как вы они пользуются картами годами и не испытывают каких либо неудобств если возникает сбой наши коллеги стараются его устранить наиболее оперативно
# я сильно уливлён
# грубо говоря по ошибке в выборку тех которые " что то химичат" вошли обычные клиенты мы это заметили и ситуацию исправили принесли извинения клиентам
# а если бы эти которые "по ошибке" не подняли бы шумиху и я уверен что таких отключенных "по ошибке" но не написавших об этом нигде очень много
# это простая логика активных пользователей соц сетей и профильных форумов очень мало или вы хотите сказать что по ошибке только они и были отключены
# да и даже не в этом дело я не понимаю вот этого отношения банка к нормальным клиентам сначала сказать что "увы до свиданья" и только спустя время уже начать разбираться и признать в итоге ошибку
# мы блокируем дистанционное обслуживание клиентам которые нарушают условия обслуживания мы никогда не скрывали этого если необходимо отключить дистанционное обслуживание мы сделаем это без каких либо прикрытий в виде сбоя
# почему бы сразу не начать разрбираться
# как ни странно но ошибку мы тоже не мгновенно обнаружили поэтому некоторое время могли сообщать стандартную фразу
# и вот за это вам огроменный минус
# я всегда был вашим лояльным клиентом и всем вас советовал
# банк не скрывает что вина на нашей стороне но повторюсь те клиенты которые пользуются счетами без нарушений продложают это делать
# но то что происходит в этой ситуации это уже за гранью
# сбои и человеческий фактор это те явления которые в том числе банкам
# так вы поймите меня правильно ребята которых отключили "по ошибке" тоже были нормальными клиентами насколько я понимаю как и я
# нет
# но теперь я понимаю что банк меня как нормального клиента может отключить в любой момент
# а потом ссылаться на какие то пункты укбо и говорить "увы решение пересмотру не подлежит "
# чтобы правильно оцентить данную ситуацию необходимо знать ее комплексно вы сейчас ознакомлены только с позицией одной стороны
# как это нет ошибку то признали признали извинилась да мили какие то начислили в качестве компенсации тоже да и они не нормальные
# всё возможно
# 11 11 | имя грубо говоря по ошибке в выборку тех которые " что то химичат" вошли обычные клиенты мы это заметили и ситуацию исправили принесли извинения клиентам
# но мне как клиенту и не зачем знать ситуацию со всех сторон я лишь смотрю на ответы и действия представителей банка
# поставьте себя на моё место
# действия просты ошибка исправлена те клиенты которые нарушают условия лишены дистанционного обслуживания
# я вижу что нормального клиента сначала грубо говоря посылают в ответ на его публичную жалобу а затем когда шум поднялся говорят "ой ошибочка вышла извините"
# как мне на это реагировать
# видимо об ошибке стало известно не сразу
# так а зачем сразу то посылать да ещё и публично меня это больше всего поражает
# я просто понимаю что так же и меня могут послать в три прекрасный момент ведь я вряд ли чем то отличаюсь от тех клиентов которые "по ошибке"
# и каковы теперь могут быть мои логичные шаги
# по факту обнаружения ошибки мы выполнили необходимые действия для исправления ситуации
# просто такими действиями и ответами сотрудников банк сильно подрывает к себе доверие а это три из главных активов банка это не я придумал и не только я говорю
# уф ну что вы об одном и том же
# я просто уже сообщил вам информацию по данной ситуации
# я понимаю что вам имя не приятно отвечать на мои неудобные вопросы но мне нужно понять отношение к клиенту банка в целом
# мы не можем гарантировать что все клиенты будут всегда с дистанционным обслуживанием
# вы просто можете перевести меня на старшего специалиста если это возможно
# возможно он мне даст понять актуальное состояние в банке
# сейчас прошу ожидать несколько минут
# тем более что я сейчас выбираю банк для открытия р/с компании
# не хотелось бы ошибиться
# окей спасибо
# прошу еще ожидать сотрудник скоро освободится
# хорошо
# я переключаю оставайтесь в чате
# ок
# здравствуйте
# подождите пожалуйста я ознакомлюсь с перепиской 1 1 минуты
# добрый день вы можете прочитать предыдущую переписку с имя но
# вкратце вопрос такой
# могут ли меня в три прекрасный день отключить от до а затем на мою жалобу просто говорить не разбираясь в сути дела "увы решение пересмотру не подлежит "
# переписка большая еще пару минут пожалуйста
# хорошр
# большое спасибо за ожидание
# имя отчество ваш вопрос и беспокойство я понимаю но как имя неоднократно писал ограничение дистанционного обслуживания действительно возможно в данном случае к сожалению оно произошло из за технического сбоя потробвалось некоторое время чтобы разобраться в ситуации и устранить неполадки
# устранены они не только для тех кто обратился но и для всех клиентов кто попал под действие данных неполадок
# специалисты которые послали клиентов до того как разобрались в проблеме уже уволены ;
# действительно это крайне неприятная ситуация
# пока нет посмотрим на их поведение
# а если серьезно еще раз извиняюсь сработало в данном случае не слишком оперативное обнаружение проблемы
# потому сотрудники видя соответствующую блокировку и информировали о невозможности ее снятия так как в случаях отличных от сбоя это действительно невозможно
# я конечно всё понимаю могу и быть сбор и человеческий фактор но дайте мне совет как вести себя в потенциально возможной как я сейчас уже понимаю ситауции когда
# когда меня внезапно блокируют а я зарубежом например а затем говорят "увы решение пересмотру не подлежит"
# что мне тогда делать
# поднимать шумиху в инете и сми
# только так вопросы решаются
# блин дурацкая автокоррекция
# имя отчество дайте мне пару минут
# а тороплюсь писать и не проверяю потому что тут у вас слишком короткий тайм аут
# и вы вроде не видите когда клиент набирает сообщение
# окей
# имя отчество действительно можем не видеть когда вы пишете это касается определенных платформ этот вопрос решается
# и кстати каким образом вообще возможно отключение от до если суд постановил что это не законно да я слышал что банк с этим не согласен и будет обжаловать решение но разве если решение суда вступило в силу банк не должен ему подчиняться
# по поводу подобных ситуаций еще раз отмечу что такое может быть по 1 причинам в рамках сбоя тогда вопрос решается достаточно оперативно так как вины клиента нет второе и это да недавних пор было единственной причиной действительно подобный сбой у нас первый и будетм надяться в последний раз ограничение может быть введено если клиент со своей стороны нарушает действующий договор
# получается что банк действует вопреки решению суда
# назвать точные причины по конкретным случаям не могу по причинам конфиденциальности но поверьте эти причины есть в качестве примера можно привести пункт 1 1 1 общих условий открытия ведения и закрытия счетов физических лиц а также выпуска и обслуживания расчетных карт
# меня на самом деле больше волнует не технический сбой
# банк уже обжалует данное решение
# таким образом в законную силу оно не вступило суд принял решение у банка есть сроки на его обжалование банк в них уложился процесс продолжается
# да они могут иметь место особенно когда банк улучшает какие то алгоритмы связанные с b d автоматизация это хорошо но
# пока всё работает не супер отлажено решения так или иначе принимают люди
# окончательное да вы правы
# и тут архиважным является то какой является первоначальная реакция банка на обращения и/или жалобы клиента
# ваши сотрудники обязаны быть более внимательными если они заинтересованы в сохранении доверия к банку со сторону клиентов
# как только стало ясно что речь идет о сбое банк оперативно среагировал на ситауцию действительно с вами я полностью согласен важно именно первое обращение в том числе роль в устранении сбоя сыграло и информирование со стороны клиентов
# а если они просто глядят что им выдает база данных в отношении того или иного клиента и затем сразу его "посылают" по совету "компьютера"
# имя отчество это издержки работы организации имеющей миллионы клиентов
# как это плохо выглядит с точки зрения других клиентов а в современной век открытости и доступной инфы подобные ситуации раскрываются очень быстро вам ли не знать
# не надо ссылаться на издержки и на миллионы
# работайте над персоналом ёмаё пока он играет роль
# миллионы никакой роли не играют вы не самый большой банк в мире
# действительно информация становится открытой и банк понес репутационные издержки в данной ситуации работа виновных в данной ситуации несомненно будет оценена по достоинству
# мы действительно не самый большой банк в мире однако не ошибается тот кто ничего не делает вопрос только в том насколько оперативно устранаются последствия таких ошибок и появляются ли последствия вообще
# верно равно как и в том как ответственные даже не рядовые сотрудники относятся к клиентам и их проблемам в общем мне в целом всё понятно спасибо вам за ваше время и ответы для себя я выводы сделал
# могу лишь сказать что теперь я не так доверяю банку как раньше но в этом вряд ли есть ваша вина имя
# и увы советать вас кому либо с чистой совестью вряд ли смогу в ближайшее время
# а так буду следить за новостями ;
# имя отчество ваши выводы мне ясны я могу со своей стороны заверить вас что подобные ситуации действительно единичны и оперативно устраняются данная получилась достаточно резонансной но поверьте в любой ситуации банк отличает сбой от верных причин и решает проблемы оперативно
# честно говоря не знаю зачем я обратился в чат и чего я ждал
# ну буду надеяться что это действительно так
# я на самом деле понимаю причины по которым вы обратились действительно неприятно попасть в такую ситуацию и хочется себя обезопасить
# от себя могу пожелать сотрудникам банка большей внимательность чуткости и человечности они очень важны в бизнес модели банка 11 века
# имя отчество перед вами сейчас стоит 1 примера 1 сбой который вас не затронул о ситуации вы знаете насколько я понял только от 1 их лиц 1 опыт личного общения ит взаимодействия с банком
# скажите пожалуйста что из этого все же перевешивает
# дело не только в этом
# и
# просто последнее время достаточно не очень приятных "мелочей"
# ну а это ситуация в который оказались нормальные клиенты на месте который мог бы легко оказаться и я просто резко перепронила чашу
# почему то всё чаще стало хотеться ставить вам в пример рокетбанк
# имя отчество просто как пример 11 11 1111 года тоже пострадало достаточное количество нормальных клиентов причем действительно понесло серьезные потери а началось все с технической причины в нашей же ситации безвозвратных потерь не произошло и слава богу
# точнее конкретно их взаимодействие с клиентами
# то как они это делают
# ммм я крайне надеюсь что вы не про пример с изъятием вкладов в интеркоммерце
# тоже не без косяков конечно
# не я не про интеркоммерц у которого знаю что отозвали лицензию
# мне кстати асв уже вернули оттуда денюжку
# это опять же как пример того что не ошибается тот кто ничего не делает
# на новую карту открытия которую мне бесплатно доставили в тай курьером
# я не о банке
# я тоже
# а о конкретно клиентской поддержке
# просто это мой личный "юзер экспириенс" так сказать
# общение с поддержкой тинькоффа и рокета
# имя отчество давайте мы с вами если позволите перейдем к более предметному разговору если речь идет о клиентской поддержке то напишите пожалуйста в чем именно у вас остался "осадок" после общения с нами
# раньше я не видел разницы рокет был просто забавным
# сейчас вижу
# это сложно выразить каким то одним конкретным примером или двумя большинство сотрудников поддержки и кц почти всех банков отвечают как роботы
# к сожалению тинькофф в этом отношении не далеко ушёл он конечно лучше многих но всё ж
# конкретно этот чат технически не доработан ну я уже говорил об этом писал тут раньше несколько дней или недель назад
# просто если рассматривать сбои и массовые проблемы то они имеют место во всех организациях равно как и реакция на данные ситуации кто то с ними сталкивается кого то они не затрагивают относительно общения полностью с вами согласен есть куда расти и мы растем растим профессионалов как среди сотрудников кц так и среди наших секторов
# слишком быстро сбрасывают клиента пока он набирает сообщение понимаю регламент но это кривой регламент
# это замечательно
# я просто как клиент и говорю что именно и конкретно во взаимодействии с клиентом хочется ставить вам в пример рокет который тоже не идеален но ведь нет в мире совершенства
# кстати очень круто что тинькофф вообще чат добавил в приложение
# чату нашему тоже не столь много времени сейчас тестируем режимы регламенты меняем поверьте сейчас справа от меня висит регламент о котором еще несколько недель наз даже не думали постоянный рост несомненно рождает и проблемы роста но мы с ними справимся
# видимо глядя на рокет ;
# назад
# я бы сказал нет но вы же не поверите
# хехехе
# вообще конечно хочется пожелать успеха банку
# и может даже как то помочь что ли
# не только для себя или для банка
# ведь если банк станет лучше другие будут брать пример а здоровая конкуренция это всегда хорошо и развитие
# мы всегда открыты для предложений имя отчество если у вас будут интересные идеи пишите
# насчет примера уже берут как ни крути
# и в итоге всем клиентам станет лучше
# и банку потому что к нему пойдут новые клиенты
# а как собственно я могу писать о предожениях замечаниях и своём ux надеясь что помогаю банку напрямую ответственным за это сотрудникам минуя "роботов" и рядовых специалистов
# по моему опыту не все из них заинтересованы в развитии своей компании и пожелания клиентов "наверх" не передают
# поверьте то что вы доносите "роботам" в любом случае доходит до того кому оно предназначено если не доходит это вина конкретного сотрудника и банк будет решать вопрос о его компетентности
# ну окей
# вы можете отправлять ваши предложения как в наши группы с соцсетях так и в чат можно позвонить или написать е мейл как вам удобно мы действительно очень ценим ваше стремление недавние награды как раз в соцсетях это доказали
# награждения
# не в курсе о награждениях ну да ладно кстати пока вспомнил последние пару недель приложение гораздо чаще стало тормозить и вылетать
# в какой конкретно момент это началось сказать не могу
# можете дать кртакую информацию версия ос версия приложения устройство
# я передам коллегам посмотяр возможные причины
# посмотрят
# вход в инет банк через веб интерфейс тоже тормозит и глючит последние несколько недель сначала списывал это на не очень быстрый тайский инет но ведь всякие другие инет банки у меня шустрее тут работают
# сейчас кину скриншоты
# a p s a 1 1 1
# могу ещё на 1 андроид 1 1 попробовать на нём просто пока нет приложения
# ещё такое замечание по приложению когда спустя время запускаешь его вновь вводишь код доступа попадаешь в раздел в котором был в последний раз
# информацию я коллегам передал они посмотрят и проинформируют вас в течение 1 календарного дня sms сообщением или звонком отслеживать статус обращения вы можете в интернет банке в разделе «связь с банком» или в приложении
# и когда в этом разделе нажимаешь клавишу "назад" чтоб выйти в меню приложения или на его главный экран вместо этого вообще происходит выход из приложения и приходится заново входить
# это происходит почти всегда и иногда раздражает
# а вот этот момент сам замечал добавлю ваш 1
# по поводу смс или звонка в этом смысла нет симкой российской не пользуюсь
# так как за рубежом
# напишу чтобы по е мейл ответили подойдет
# да отлично
# кстати пуш уведомления приходят очень выборочно хотя включены
# около 11% пушей продолжают приходить смсками
# в смысле 11% уведомлений и кодов подтверждения операций
# вместо пуш приходят смс
# пока что в виде sms по прежнему приходят коды если вы совершаете операцию в интернете увежомлениями отправляются только коды для мобильного приложения
# уведомлениями
# вот тут в чате пытаюсь посмотреть переписку выше но меня всё время кидает в самый низ когда вы что то набираете не удобно и менее спокойного человека начало бы бесить
# ясно ладно
# ну касаемо не очень приятных изменений в тарифах это совсем из другой оперы думаю смысла нет
# по поводу перекидывания на самом деле это для удобства чтобы вам не скроллить вниз передам коллегам как пожелание пусть подумают что можно сделать
# посмотреть как это сделано в том же телеграме например
# просто появляется значок возврата в самый низ
# такое автоперекидывание вниз совсем не удобно
# тарифы ну на самом деле задевает в основном тех у кого нет вкладов и кто не хочет пользоваться картой по сути банк разграничивает продукты есть вклады накопительные счета для сохранения а есть карта для использвания средств
# а есть ещё кредитная карта которой в основном и пользуешься
#
# а сейчас получается придется пользоваться дебетовой
# что не очень интересно или выводить с неё все средства
# как будто банку не нужны деньги впрочем думаю специалисты всё рассчитали и много банк от этого не потеряет отток средств с карт вряд ли будет большой
# тут уже не в моей компетенции обсуждать или осуждать данные нововведения думаю вы понимаете несоменно перед введением аналитики производили расчеты
# мне советовали открывать накопительный счёт но это менее удобно нежели % на остаток по карте к тому же там ставка не очень в сравнении с другими банками ну тут ладно это другой вопрос в банке думаю всё рассчитали
# ну да я об этом и говорю
# ну да ставка там на 1% пониже зато нет платы за обслуживание нет каких либо минимальных сумм
# а какой кстати должен быть там минимальный остаток чтоб за обслуживание белковой карты не описывали
# белковой
# белковой
# дебетовой
# не списывали
# 11 111 руб неснижаемый
# а ну тоже самое как и на карте а если депозит в смысле вклад тогда от 11 т
# так я про карту и говорил наверное неправильно вас понял накопительные счета никак не влияют на списание платы за обслуживание
# кстати в чате отражается время сообщений по москве
# а тут у меня например уже 11 11
# а в чате время сообщений 11 11
# мелочь но не совсем корректно всё ж
# а получается если я с карты переведу почти всё на накопительный 11р по карте всё равно будет ежемесячно списываться
# тогда ещё менее удобно и менее выгодно
# да время берется московское так на самом деле удобнее при повторных обращениях по ранним чатам определять о каком именно сообщении идет речь к примеру вы будете недовольны мой фразой сказанной к примеру в 11 11 но ваши 11 11 и 11 11 банка разные 11 11 потому может произойти недопонимание
# плату за обслуживание по расчетной карет мы не списываем если на ней нет средств вообще
# карте
# не совсем конечно понятно зачем клиента заставлять тратить 1 тысячи по дебетовой если он использует в основном только
# а ну да своя логика в этом есть с часовым поясом хотя может и можно это как то улучшить например запрашивать у приложения часовой пояс клиента и затем корректировать время сообщений на сервере ну или как то так
# ну если средств на карте нет это да понятно хотя совсем всё с карты выводить не хочется
# хм в этом случае ваши 11 11 все еще отличаются от моих 11 11 по поводу списания можно ведь держать 11 111 руб на карте или открыть вклад
# да но тогда не будут % начисляться если не тратить 1 тыщи по дебетовой
# странно что расходов по кредитной не достаточно
# вклад отдельная тема мне пока не очень удобная
# это да верно ну а расходы по кредитной карте все же расходы по абсолютно иному продукту
# ясно но можно было бы и объединить в смысле смотреть в целом активность клиента по всем картам и потом уже решать начислять проценты на остаток или нет ну банку вмднее
# ну в общем ладно спасибо вам за беседу надеюсь как то помогаю становиться банку лучше
# действительно помогаете рад был общению если появятся вопросы обращайтесь
# хорошо спасибо всего доброго
# хорошего вам дня хотя у вас уже скорее "хорошего вечера"
# да
# кстати ещё совет
# пока помню
# да какой
# можно было бы сюда в чат добавить голосовые сообщения как в мессенджерах
# не всегда удобно набирать длинный текст
# да и эмоции и интонации клиента лучше понятны из голоса нежели чем из текста
# вы имеете ввиду голосовые сообщения или голосовой набор
# сообщения голосом нажал кнопку наговорил сообщение отпустил кнопку сообщение в виде аудио отправилось в банк
# понял о чем вы
# голосовой набор это и так есть в андроиде да и в айос вроде уже тоже
# основной минус поиск по ним не работает
# но ведь можно просто позвонить из приложения впрочем суть вашего предложения понятна коллегам на рассмотрение тоже отправлю
# а кстати тут в чате и так поиска нет у клиента тоже можно было бы добавить
# есть еще 1 минус может получиться так что устная речь банкально будет невнятной / неясной
# звонить не всегда удобно
# банально
# и не всегда скорость инета для этого достаточна
# ну так она и при звонке тогда такой же будет
# верно зато письменно получается лучше
# ну тоже когда как
# не спорю случаи бывают разные
# и главное не понятны интонации и эмоции клиента
# ну это просто думаю удобная для клиента опция а ваши спецы уже сами решат стоит ли она того или нет
# большинство наверное всё равно будут текст набирать по крайней мере первое время
# сложность ещё и в хранении всех этих аудио ну и траффик
# к слову от траффике передача то тоже за ваш счет будет
# да для клиента это мизер тем более когда инет анлимит или большие пакеты а вот банку на кучу клиентов да чуть больше расходов
# а значит и выше себестоимость услуг
# впрочем не знаю может в сравнении с другими расходами тоже не большая разница
# ладно ещё раз вам всего доброго и приятных выходных приятно пообщаться с адекватным сотрудником банка таким как вы имя
# всего доброго вам имя отчество
# эмодзи ещё добавьте
# иногда их не хватает
# я серьёзно
# такое предложение уже есть действительно их не хватает приходится выдумывать что то из знаков препинания
# общение будет более человечное
# ага ;
# ладно я побежал удачи вам имя
# ну и банку тоже
# до свидания

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences, min_count=1, sg=1, size=200, iter=8, workers=4)

# %%
model.most_similar(['карта'])
# Out:
# [('дебетовая', 0.7837350368499756),
#  ('кредитная', 0.7288051247596741),
#  ('рублевая', 0.6853181719779968),
#  ('виртуальная', 0.6527940034866333),
#  ('карточка', 0.6482224464416504),
#  ('валютная', 0.6476641893386841),
#  ('выпущена', 0.6411604881286621),
#  ('заблокирована', 0.6320291757583618),
#  ('перевыпущенная', 0.6306322813034058),
#  ('активирована', 0.6236859560012817)]

# %%
model.most_similar(positive=['блонд', 'вопрос'], negative=[])
# Out:
# [('лайки', 0.7922518253326416),
#  ('обжаловать', 0.7867491245269775),
#  ('"рассмотрению"', 0.7830104231834412),
#  ('наткнуться', 0.7827651500701904),
#  ('родили', 0.7825422883033752),
#  ('расстроился', 0.7815518379211426),
#  ('обдираловки', 0.7814565896987915),
#  ('вопром', 0.7810412645339966),
#  ('уточнать', 0.7798020839691162),
#  ('торопят', 0.7788264751434326)]

# %%
model.doesnt_match(["", "кредитная", "дебетовая", "карта"])
# Out:
# 'банк'

# %%
model.most_similar(['изъять'])
# Out:
# [('вывести', 0.714593768119812),
#  ('изымать', 0.669033408164978),
#  ('изымаете', 0.6518428921699524),
#  ('изъяли', 0.6512863636016846),
#  ('средства1', 0.6250762343406677),
#  ('перевести', 0.6152870655059814),
#  ('изымите', 0.6139361262321472),
#  ('переведете', 0.6119550466537476),
#  ('поступившую', 0.6117496490478516),
#  ('переведенную', 0.5980391502380371)]

# %%
from scipy.spatial.distance import cosine 
def relevance(phrase):
    ans = sum([model[word] for word in phrase])
    for word in phrase:
        print(word, 1 - cosine(model[word], ans))
string = """
Как узнать кредитный лимит по карте
Здравствуйте
Доброй ночи 
Сейчас проверю информацию, 1-1 минуты, пожалуйста. 
Жду, спасибо! 
Кредитный лимит по Вашей карте - 111 тысяч. Вы можете эту информацию посмотреть в приложении. 
Спасибо, а где в приложении? 
Для этого нужно выбрать карту в разделе "Счета". 
Далее нажать меню в правом верхнем углу. 
Спасибо! Супер! 
Рад помочь! Удачи Вам и всего доброго!
""".lower()
string = " ".join(re.split(r"[\(\)-\.!?\s]+", string))
print(string)
relevance(string.split())
# Out:
#  как узнать кредитный лимит по карте здравствуйте доброй ночи сейчас проверю информацию 1 1 минуты пожалуйста жду спасибо кредитный лимит по вашей карте 111 тысяч вы можете эту информацию посмотреть в приложении спасибо а где в приложении для этого нужно выбрать карту в разделе "счета" далее нажать меню в правом верхнем углу спасибо супер рад помочь удачи вам и всего доброго
# как 0.520659037088
# узнать 0.526173628831
# кредитный 0.508053718692
# лимит 0.513312941602
# по 0.539146588713
# карте 0.550655852088
# здравствуйте 0.547327298606
# доброй 0.590043880599
# ночи 0.517373147653
# сейчас 0.605525833231
# проверю 0.595267208653
# информацию 0.595682060604
# 1 0.569610360739
# 1 0.569610360739
# минуты 0.568633441506
# пожалуйста 0.621344547647
# жду 0.400422791356
# спасибо 0.571463339256
# кредитный 0.508053718692
# лимит 0.513312941602
# по 0.539146588713
# вашей 0.492158218098
# карте 0.550655852088
# 111 0.516834143521
# тысяч 0.507252646703
# вы 0.541837858386
# можете 0.565875162058
# эту 0.486023992358
# информацию 0.595682060604
# посмотреть 0.569025665457
# в 0.608233106614
# приложении 0.577955737654
# спасибо 0.571463339256
# а 0.532745986513
# где 0.48341175036
# в 0.608233106614
# приложении 0.577955737654
# для 0.512144254326
# этого 0.529124221759
# нужно 0.564703678697
# выбрать 0.50729197085
# карту 0.499276174744
# в 0.608233106614
# разделе 0.56666210367
# "счета" 0.582466189386
# далее 0.48253026583
# нажать 0.517366090257
# меню 0.521983347001
# в 0.608233106614
# правом 0.617475841534
# верхнем 0.618879972944
# углу 0.598706925021
# спасибо 0.571463339256
# супер 0.476504046691
# рад 0.560733057624
# помочь 0.59762313045
# удачи 0.489731096911
# вам 0.597607201349
# и 0.536293525939
# всего 0.619862425155
# доброго 0.624561719265

# %%
model.most_similar(positive=['один', 'момент', 'уточняю'])
# Out:
# [('профильм', 0.6872949004173279),
#  ('исправлюсь', 0.656134307384491),
#  ('уточнении', 0.6490548849105835),
#  ('сойдет', 0.6454126834869385),
#  ('неизменны', 0.6421858072280884),
#  ('безработная', 0.6403404474258423),
#  ('расследований', 0.6371269226074219),
#  ('задступ', 0.6345673203468323),
#  ('оставйтесь', 0.6342647671699524),
#  ('храни', 0.6337534785270691)]
